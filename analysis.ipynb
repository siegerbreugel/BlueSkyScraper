# %%
import os
import datetime
import pytz

import pandas as pd
from dotenv import load_dotenv

from BlueSkyScraper import BlueSkyScraper

# Initialize environment variables
load_dotenv()
BLUESKY_USER = os.getenv('BLUESKY_USER')
BLUESKY_PASSWORD = os.getenv('BLUESKY_PASSWORD')

# Initialize scraper with user credentials
scraper = BlueSkyScraper()
scraper.login(BLUESKY_USER, BLUESKY_PASSWORD)

# Get the posts
start_date = datetime.datetime(2025, 10, 16, tzinfo=pytz.timezone('America/New_York'))
end_date = datetime.datetime(2025, 11, 4, tzinfo=pytz.timezone('America/New_York'))

posts = scraper.search_posts('Mamdani', start_date=start_date, end_date=end_date, limit=10)

# Pandas
df = pd.json_normalize(posts['posts'])
df.head()
# Out:
#                                                  cid  \
# 0  bafyreiaq42ubrv5y5juge4tqzvg3z65p3nwwoobn5xjkd...
# 1  bafyreicq3rjh2ttfgcyd3yfhbcpiilfqhyj7s35rdghqj...
# 2  bafyreicuabgakiqq3rzhceffeatdyfvbvgpywrdw2xrss...
# 3  bafyreifox7hm5as4tea72u5nn3nq56b3b25gnyaztlckt...
# 4  bafyreia4fxyoeezxmakpblv7tl4ujzbvaupltjieg62jh...
#
#                  indexed_at  \
# 0  2025-11-03T23:59:56.257Z
# 1  2025-11-03T23:59:43.759Z
# 2  2025-11-03T23:59:40.759Z
# 3  2025-11-03T23:59:39.659Z
# 4  2025-11-03T23:59:39.162Z
#
#                                                  uri  bookmark_count debug  \
# 0  at://did:plc:qw57zt5wkne2fen4n63tvjvq/app.bsky...               0  None
# 1  at://did:plc:jjz2j2yqtgagnzwkffju4bg5/app.bsky...               0  None
# 2  at://did:plc:vk52fnrcwlzgd3zydj6535mn/app.bsky...               0  None
# 3  at://did:plc:lvglyu7zbigx3xoovg65qrad/app.bsky...               0  None
# 4  at://did:plc:vrnjqa3bd5ichszr6whu2nbx/app.bsky...               0  None
#
#   labels  like_count  quote_count  reply_count  repost_count  ...  \
# 0     []           5            0            1             3  ...
# 1     []           0            0            1             0  ...
# 2     []           0            0            0             0  ...
# 3     []           0            1            2             0  ...
# 4     []           3            0            0             0  ...
#
#    threadgate.record.post threadgate.record.allow  \
# 0                     NaN                     NaN
# 1                     NaN                     NaN
# 2                     NaN                     NaN
# 3                     NaN                     NaN
# 4                     NaN                     NaN
#
#   threadgate.record.hidden_replies threadgate.record.py_type threadgate.uri  \
# 0                              NaN                       NaN            NaN
# 1                              NaN                       NaN            NaN
# 2                              NaN                       NaN            NaN
# 3                              NaN                       NaN            NaN
# 4                              NaN                       NaN            NaN
#
#   threadgate.py_type embed.record.author.verification.trusted_verifier_status  \
# 0                NaN                                                NaN
# 1                NaN                                                NaN
# 2                NaN                                                NaN
# 3                NaN                                                NaN
# 4                NaN                                                NaN
#
#   embed.record.author.verification.verifications  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   embed.record.author.verification.verified_status  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   embed.record.author.verification.py_type
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
# [5 rows x 150 columns]

# %%
import pandas as pd
import json

posts = json.load(open('./examples/scraped_posts_2025-12-03_18-41-34.json'))
df = pd.json_normalize(posts)
df.head()
# Out:
#                                                  cid  \
# 0  bafyreihvvdipczepceyxxxmuxtwhpl5vvi7qijikeiitr...
# 1  bafyreibuwvjkjuruxgtqhyw6attwpktu5ceop23tuitkf...
# 2  bafyreibdjejgkbrdqx3f2g4fg5ahv2gwqjdaehbpll4pc...
# 3  bafyreiffktcw6vpbtt33mukspiauvujctgxtmquq36mdg...
# 4  bafyreihglrekfokegb6m7aq4iwn26ywr4nfnqvtewwu3z...
#
#                  indexed_at  \
# 0  2025-12-01T00:59:29.533Z
# 1  2025-12-01T01:57:22.434Z
# 2  2025-12-01T02:58:33.034Z
# 3  2025-12-01T03:57:28.833Z
# 4  2025-12-01T04:50:14.032Z
#
#                                                  uri  bookmark_count debug  \
# 0  at://did:plc:ceure4mfaxd3gh4fbkcvp2je/app.bsky...               0  None
# 1  at://did:plc:do46s3u6h22vzu6nogkm4rc7/app.bsky...               0  None
# 2  at://did:plc:f42ntlx4xz4bo3eabvlcpdrv/app.bsky...               0  None
# 3  at://did:plc:bfctdt64ifpjcajketysws2t/app.bsky...               0  None
# 4  at://did:plc:i53e6y3liw2oaw4s6e6odw5m/app.bsky...               0  None
#
# ...
